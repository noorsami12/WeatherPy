# %%
# Importing dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import api_key

import time

# %%
# Create a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Base URL for Weather Map API Call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    #try:
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    # Parse out the needed data.
    try:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"] 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descrip})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | kiama
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | along
# Processing Record 6 of Set 1 | calvinia
# Processing Record 7 of Set 1 | cascais
# Processing Record 8 of Set 1 | hirara
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | guerrero negro
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | vardo
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | gillette
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | rodos
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | marawi
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | sulangan
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | waipawa
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | hervey bay
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | kieta
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | vanimo
# Processing Record 44 of Set 1 | batagay
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | cap malheureux
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | mahon
# Processing Record 1 of Set 2 | pacifica
# Processing Record 2 of Set 2 | muravlenko
# Processing Record 3 of Set 2 | san francisco
# Processing Record 4 of Set 2 | sioux lookout
# Processing Record 5 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 2 | zhanjiang
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | mount gambier
# Processing Record 9 of Set 2 | weligama
# Processing Record 10 of Set 2 | adrar
# Processing Record 11 of Set 2 | padang
# Processing Record 12 of Set 2 | tigre
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | heihe
# Processing Record 15 of Set 2 | vertientes
# Processing Record 16 of Set 2 | san vicente de canete
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | chikoy
# City not found. Skipping...
# Processing Record 19 of Set 2 | dandong
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | kenai
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | saint-georges
# Processing Record 25 of Set 2 | monrovia
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | narrabri
# Processing Record 28 of Set 2 | zabolotiv
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 2 | bathsheba
# Processing Record 36 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 2 | alice springs
# Processing Record 38 of Set 2 | margate
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | tabriz
# Processing Record 41 of Set 2 | flinders
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | grand gaube
# Processing Record 47 of Set 2 | plerin
# Processing Record 48 of Set 2 | ban nahin
# Processing Record 49 of Set 2 | hay river
# Processing Record 50 of Set 2 | santa cruz
# Processing Record 1 of Set 3 | los llanos de aridane
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | emirdag
# Processing Record 4 of Set 3 | malinovskiy
# Processing Record 5 of Set 3 | lukovetskiy
# Processing Record 6 of Set 3 | abu kamal
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | brae
# Processing Record 9 of Set 3 | muscle shoals
# Processing Record 10 of Set 3 | rio gallegos
# Processing Record 11 of Set 3 | honavar
# Processing Record 12 of Set 3 | tamale
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | aleksandrov gay
# Processing Record 16 of Set 3 | bela
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | jiuquan
# Processing Record 19 of Set 3 | prince rupert
# Processing Record 20 of Set 3 | saint-augustin
# Processing Record 21 of Set 3 | kemise
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | jiayuguan
# Processing Record 24 of Set 3 | plettenberg bay
# Processing Record 25 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 3 | tazovskiy
# Processing Record 29 of Set 3 | port washington
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | anadyr
# Processing Record 32 of Set 3 | chernyshevskiy
# Processing Record 33 of Set 3 | vao
# Processing Record 34 of Set 3 | yinchuan
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | okhotsk
# Processing Record 37 of Set 3 | punta arenas
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | fukue
# Processing Record 40 of Set 3 | charleston
# Processing Record 41 of Set 3 | myaundzha
# Processing Record 42 of Set 3 | skelleftea
# Processing Record 43 of Set 3 | qaqortoq
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | bull savanna
# Processing Record 46 of Set 3 | yerbogachen
# Processing Record 47 of Set 3 | labuhan
# Processing Record 48 of Set 3 | lagoa
# Processing Record 49 of Set 3 | lasa
# Processing Record 50 of Set 3 | balkhash
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | mae sai
# Processing Record 3 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 4 | korla
# Processing Record 5 of Set 4 | evensk
# Processing Record 6 of Set 4 | solwezi
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | vanavara
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 4 | oranjemund
# Processing Record 14 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | djambala
# Processing Record 16 of Set 4 | katobu
# Processing Record 17 of Set 4 | ocean city
# Processing Record 18 of Set 4 | teguise
# Processing Record 19 of Set 4 | samarai
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | hami
# Processing Record 22 of Set 4 | mount isa
# Processing Record 23 of Set 4 | lesnoy
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | shreveport
# Processing Record 26 of Set 4 | kwinana
# Processing Record 27 of Set 4 | tuktoyaktuk
# Processing Record 28 of Set 4 | alofi
# Processing Record 29 of Set 4 | south valley
# Processing Record 30 of Set 4 | dikson
# Processing Record 31 of Set 4 | saravan
# Processing Record 32 of Set 4 | banjar
# Processing Record 33 of Set 4 | makakilo city
# Processing Record 34 of Set 4 | muros
# Processing Record 35 of Set 4 | chingirlau
# Processing Record 36 of Set 4 | ostrovnoy
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | santa rosa
# Processing Record 39 of Set 4 | zhanaozen
# Processing Record 40 of Set 4 | bintulu
# Processing Record 41 of Set 4 | erzin
# Processing Record 42 of Set 4 | rawson
# Processing Record 43 of Set 4 | westport
# Processing Record 44 of Set 4 | bulz
# Processing Record 45 of Set 4 | tarauaca
# Processing Record 46 of Set 4 | miracema do tocantins
# Processing Record 47 of Set 4 | grand forks
# Processing Record 48 of Set 4 | palu
# Processing Record 49 of Set 4 | upernavik
# Processing Record 50 of Set 4 | hobart
# Processing Record 1 of Set 5 | dicabisagan
# Processing Record 2 of Set 5 | yumen
# Processing Record 3 of Set 5 | marystown
# Processing Record 4 of Set 5 | airai
# Processing Record 5 of Set 5 | roros
# Processing Record 6 of Set 5 | ballitoville
# Processing Record 7 of Set 5 | pak phanang
# Processing Record 8 of Set 5 | saint-francois
# Processing Record 9 of Set 5 | gizo
# Processing Record 10 of Set 5 | nioro
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | sukhinichi
# Processing Record 13 of Set 5 | saint george
# Processing Record 14 of Set 5 | pochutla
# Processing Record 15 of Set 5 | butaritari
# Processing Record 16 of Set 5 | daru
# Processing Record 17 of Set 5 | annau
# Processing Record 18 of Set 5 | tual
# Processing Record 19 of Set 5 | torrox
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | hermanus
# Processing Record 23 of Set 5 | saldanha
# Processing Record 24 of Set 5 | bulungu
# Processing Record 25 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 5 | lorengau
# Processing Record 27 of Set 5 | saint-ambroise
# Processing Record 28 of Set 5 | sinjah
# City not found. Skipping...
# Processing Record 29 of Set 5 | bundaberg
# Processing Record 30 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 5 | shenjiamen
# Processing Record 32 of Set 5 | tondano
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | lerwick
# Processing Record 35 of Set 5 | karwar
# Processing Record 36 of Set 5 | hays
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | roma
# Processing Record 42 of Set 5 | ahipara
# Processing Record 43 of Set 5 | carrollton
# Processing Record 44 of Set 5 | la primavera
# Processing Record 45 of Set 5 | upata
# Processing Record 46 of Set 5 | bushehr
# Processing Record 47 of Set 5 | kamenka
# Processing Record 48 of Set 5 | price
# Processing Record 49 of Set 5 | kaitangata
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | lumeje
# Processing Record 2 of Set 6 | mar del plata
# Processing Record 3 of Set 6 | mahebourg
# Processing Record 4 of Set 6 | khatanga
# Processing Record 5 of Set 6 | panlaitan
# Processing Record 6 of Set 6 | iranshahr
# Processing Record 7 of Set 6 | tecoanapa
# Processing Record 8 of Set 6 | lompoc
# Processing Record 9 of Set 6 | mago
# Processing Record 10 of Set 6 | luksuhin
# Processing Record 11 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 6 | tura
# Processing Record 13 of Set 6 | marzuq
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | port moresby
# Processing Record 16 of Set 6 | george town
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | solnechnyy
# Processing Record 19 of Set 6 | mizur
# Processing Record 20 of Set 6 | harper
# Processing Record 21 of Set 6 | sarkand
# Processing Record 22 of Set 6 | maltahohe
# Processing Record 23 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 24 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 6 | port hardy
# Processing Record 26 of Set 6 | carnarvon
# Processing Record 27 of Set 6 | muisne
# Processing Record 28 of Set 6 | oromocto
# Processing Record 29 of Set 6 | tabarqah
# City not found. Skipping...
# Processing Record 30 of Set 6 | porto walter
# Processing Record 31 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 6 | qujing
# Processing Record 33 of Set 6 | norman wells
# Processing Record 34 of Set 6 | peniche
# Processing Record 35 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 6 | nabire
# Processing Record 37 of Set 6 | torbay
# Processing Record 38 of Set 6 | wad madani
# Processing Record 39 of Set 6 | rio grande
# Processing Record 40 of Set 6 | noumea
# Processing Record 41 of Set 6 | athabasca
# Processing Record 42 of Set 6 | bend
# Processing Record 43 of Set 6 | mitu
# Processing Record 44 of Set 6 | aripuana
# Processing Record 45 of Set 6 | bakuriani
# Processing Record 46 of Set 6 | iralaya
# Processing Record 47 of Set 6 | keti bandar
# Processing Record 48 of Set 6 | da lat
# Processing Record 49 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 6 | kahului
# Processing Record 1 of Set 7 | vilhena
# Processing Record 2 of Set 7 | koumac
# Processing Record 3 of Set 7 | senno
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | sasina
# Processing Record 6 of Set 7 | senanga
# Processing Record 7 of Set 7 | peterhead
# Processing Record 8 of Set 7 | souillac
# Processing Record 9 of Set 7 | moron
# Processing Record 10 of Set 7 | soledad
# Processing Record 11 of Set 7 | san patricio
# Processing Record 12 of Set 7 | turka
# Processing Record 13 of Set 7 | verkhnyaya inta
# Processing Record 14 of Set 7 | nikolskoye
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | kovdor
# Processing Record 17 of Set 7 | lexington
# Processing Record 18 of Set 7 | wladyslawowo
# Processing Record 19 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 7 | chapais
# Processing Record 21 of Set 7 | itaituba
# Processing Record 22 of Set 7 | sessa aurunca
# Processing Record 23 of Set 7 | jardim
# Processing Record 24 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 7 | naze
# Processing Record 26 of Set 7 | santa isabel do rio negro
# Processing Record 27 of Set 7 | el real de santa maria
# Processing Record 28 of Set 7 | port lincoln
# Processing Record 29 of Set 7 | khorinsk
# Processing Record 30 of Set 7 | salta
# Processing Record 31 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 7 | sakakah
# Processing Record 33 of Set 7 | nanortalik
# Processing Record 34 of Set 7 | smithers
# Processing Record 35 of Set 7 | clyde river
# Processing Record 36 of Set 7 | ixtapa
# Processing Record 37 of Set 7 | panaba
# Processing Record 38 of Set 7 | chirongui
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 41 of Set 7 | oktyabrskiy
# Processing Record 42 of Set 7 | porto novo
# Processing Record 43 of Set 7 | coihaique
# Processing Record 44 of Set 7 | inhambane
# Processing Record 45 of Set 7 | blonduos
# City not found. Skipping...
# Processing Record 46 of Set 7 | tiznit
# Processing Record 47 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 7 | parauna
# Processing Record 49 of Set 7 | san quintin
# Processing Record 50 of Set 7 | marsa matruh
# Processing Record 1 of Set 8 | aklavik
# Processing Record 2 of Set 8 | hasaki
# Processing Record 3 of Set 8 | warkworth
# Processing Record 4 of Set 8 | filingue
# Processing Record 5 of Set 8 | churapcha
# Processing Record 6 of Set 8 | neiafu
# Processing Record 7 of Set 8 | todos santos
# Processing Record 8 of Set 8 | qaanaaq
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | auburn
# Processing Record 11 of Set 8 | schwyz
# Processing Record 12 of Set 8 | ranong
# Processing Record 13 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 8 | pacific grove
# Processing Record 15 of Set 8 | mutoko
# Processing Record 16 of Set 8 | kupang
# Processing Record 17 of Set 8 | bucerias
# Processing Record 18 of Set 8 | sekoma
# Processing Record 19 of Set 8 | vrangel
# Processing Record 20 of Set 8 | gualaquiza
# Processing Record 21 of Set 8 | wahiawa
# Processing Record 22 of Set 8 | kayes
# Processing Record 23 of Set 8 | freeport
# Processing Record 24 of Set 8 | de aar
# Processing Record 25 of Set 8 | tyukhtet
# Processing Record 26 of Set 8 | prado
# Processing Record 27 of Set 8 | mangochi
# Processing Record 28 of Set 8 | la cruz
# Processing Record 29 of Set 8 | maniitsoq
# Processing Record 30 of Set 8 | itoman
# Processing Record 31 of Set 8 | myitkyina
# Processing Record 32 of Set 8 | saint-paul
# Processing Record 33 of Set 8 | beisfjord
# Processing Record 34 of Set 8 | tomakomai
# Processing Record 35 of Set 8 | kitimat
# Processing Record 36 of Set 8 | fort morgan
# Processing Record 37 of Set 8 | caldwell
# Processing Record 38 of Set 8 | pokrovskoye
# Processing Record 39 of Set 8 | rognan
# Processing Record 40 of Set 8 | umm lajj
# Processing Record 41 of Set 8 | bambous virieux
# Processing Record 42 of Set 8 | cabra
# Processing Record 43 of Set 8 | la ronge
# Processing Record 44 of Set 8 | griffith
# Processing Record 45 of Set 8 | awbari
# Processing Record 46 of Set 8 | homer
# Processing Record 47 of Set 8 | shouguang
# Processing Record 48 of Set 8 | sitka
# Processing Record 49 of Set 8 | mecca
# Processing Record 50 of Set 8 | davila
# Processing Record 1 of Set 9 | sao felix do xingu
# Processing Record 2 of Set 9 | kenora
# Processing Record 3 of Set 9 | semypolky
# Processing Record 4 of Set 9 | sept-iles
# Processing Record 5 of Set 9 | colares
# Processing Record 6 of Set 9 | luderitz
# Processing Record 7 of Set 9 | mareeba
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | kudat
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | ossora
# Processing Record 12 of Set 9 | naranjal
# Processing Record 13 of Set 9 | touros
# Processing Record 14 of Set 9 | duyun
# Processing Record 15 of Set 9 | sao miguel do araguaia
# Processing Record 16 of Set 9 | merauke
# Processing Record 17 of Set 9 | bjala
# City not found. Skipping...
# Processing Record 18 of Set 9 | george
# Processing Record 19 of Set 9 | chiochis
# Processing Record 20 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | lokosovo
# Processing Record 22 of Set 9 | inverell
# Processing Record 23 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 9 | huarmey
# Processing Record 25 of Set 9 | altay
# Processing Record 26 of Set 9 | san jeronimo
# Processing Record 27 of Set 9 | qidong
# Processing Record 28 of Set 9 | narsaq
# Processing Record 29 of Set 9 | yar-sale
# Processing Record 30 of Set 9 | nanzhou
# Processing Record 31 of Set 9 | roald
# Processing Record 32 of Set 9 | kurilsk
# Processing Record 33 of Set 9 | lodja
# Processing Record 34 of Set 9 | anqing
# Processing Record 35 of Set 9 | lagos
# Processing Record 36 of Set 9 | bilibino
# Processing Record 37 of Set 9 | popondetta
# Processing Record 38 of Set 9 | katsuura
# Processing Record 39 of Set 9 | manta
# Processing Record 40 of Set 9 | chiapilla
# Processing Record 41 of Set 9 | zharkent
# Processing Record 42 of Set 9 | kasongo-lunda
# Processing Record 43 of Set 9 | basoko
# Processing Record 44 of Set 9 | yeppoon
# Processing Record 45 of Set 9 | tautira
# Processing Record 46 of Set 9 | klaksvik
# Processing Record 47 of Set 9 | comodoro rivadavia
# Processing Record 48 of Set 9 | ilo
# Processing Record 49 of Set 9 | gondanglegi
# Processing Record 50 of Set 9 | sembakung
# Processing Record 1 of Set 10 | bira
# Processing Record 2 of Set 10 | bontang
# Processing Record 3 of Set 10 | port blair
# Processing Record 4 of Set 10 | mbanza-ngungu
# Processing Record 5 of Set 10 | oga
# Processing Record 6 of Set 10 | simeykyne
# Processing Record 7 of Set 10 | portland
# Processing Record 8 of Set 10 | vidim
# Processing Record 9 of Set 10 | isabela
# Processing Record 10 of Set 10 | xocali
# Processing Record 11 of Set 10 | hartlepool
# Processing Record 12 of Set 10 | gorgan
# Processing Record 13 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 10 | londonderry
# Processing Record 15 of Set 10 | port keats
# Processing Record 16 of Set 10 | atasu
# Processing Record 17 of Set 10 | acapulco
# Processing Record 18 of Set 10 | taoudenni
# Processing Record 19 of Set 10 | port hedland
# Processing Record 20 of Set 10 | jimo
# Processing Record 21 of Set 10 | hofn
# Processing Record 22 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 10 | koungou
# Processing Record 24 of Set 10 | saint anthony
# Processing Record 25 of Set 10 | mayumba
# Processing Record 26 of Set 10 | rundu
# Processing Record 27 of Set 10 | henties bay
# Processing Record 28 of Set 10 | amarillo
# Processing Record 29 of Set 10 | greensburg
# Processing Record 30 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 31 of Set 10 | imuris
# Processing Record 32 of Set 10 | egvekinot
# Processing Record 33 of Set 10 | nokaneng
# Processing Record 34 of Set 10 | tuatapere
# Processing Record 35 of Set 10 | hailey
# Processing Record 36 of Set 10 | chuy
# Processing Record 37 of Set 10 | bahar
# Processing Record 38 of Set 10 | ambilobe
# Processing Record 39 of Set 10 | timbiqui
# Processing Record 40 of Set 10 | aktash
# Processing Record 41 of Set 10 | ayan
# Processing Record 42 of Set 10 | leirvik
# Processing Record 43 of Set 10 | kropotkin
# Processing Record 44 of Set 10 | suluq
# Processing Record 45 of Set 10 | kamina
# Processing Record 46 of Set 10 | shelburne
# Processing Record 47 of Set 10 | bereda
# Processing Record 48 of Set 10 | kirakira
# Processing Record 49 of Set 10 | deputatskiy
# Processing Record 50 of Set 10 | te anau
# Processing Record 1 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 11 | havelock
# Processing Record 3 of Set 11 | husavik
# Processing Record 4 of Set 11 | walvis bay
# Processing Record 5 of Set 11 | tessalit
# Processing Record 6 of Set 11 | channel-port aux basques
# Processing Record 7 of Set 11 | villa vazquez
# City not found. Skipping...
# Processing Record 8 of Set 11 | matagami
# Processing Record 9 of Set 11 | aykhal
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | emilio carranza
# Processing Record 12 of Set 11 | porto santo
# Processing Record 13 of Set 11 | coahuayana
# Processing Record 14 of Set 11 | tromso
# Processing Record 15 of Set 11 | kondinskoye
# Processing Record 16 of Set 11 | shimanovsk
# Processing Record 17 of Set 11 | poum
# Processing Record 18 of Set 11 | kargopol
# Processing Record 19 of Set 11 | ust-kuyga
# Processing Record 20 of Set 11 | aksu
# Processing Record 21 of Set 11 | havoysund
# Processing Record 22 of Set 11 | skjervoy
# Processing Record 23 of Set 11 | khandyga
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | iracoubo
# Processing Record 26 of Set 11 | burica
# City not found. Skipping...
# Processing Record 27 of Set 11 | honningsvag
# Processing Record 28 of Set 11 | victor harbor
# Processing Record 29 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 11 | ola
# Processing Record 31 of Set 11 | namatanai
# Processing Record 32 of Set 11 | igrim
# Processing Record 33 of Set 11 | isangel
# Processing Record 34 of Set 11 | karangampel
# Processing Record 35 of Set 11 | turangi
# Processing Record 36 of Set 11 | shuangyang
# Processing Record 37 of Set 11 | ulverstone
# Processing Record 38 of Set 11 | rensvik
# Processing Record 39 of Set 11 | ballina
# Processing Record 40 of Set 11 | odweyne
# Processing Record 41 of Set 11 | fort nelson
# Processing Record 42 of Set 11 | orlik
# Processing Record 43 of Set 11 | povenets
# Processing Record 44 of Set 11 | lai
# Processing Record 45 of Set 11 | valdivia
# Processing Record 46 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 47 of Set 11 | zaoyang
# Processing Record 48 of Set 11 | caetite
# Processing Record 49 of Set 11 | delemont
# Processing Record 50 of Set 11 | bac lieu
# Processing Record 1 of Set 12 | nouadhibou
# Processing Record 2 of Set 12 | ploemeur
# Processing Record 3 of Set 12 | provideniya
# Processing Record 4 of Set 12 | frederick
# Processing Record 5 of Set 12 | svetlogorsk
# Processing Record 6 of Set 12 | santiago de cuba
# Processing Record 7 of Set 12 | nantucket
# Processing Record 8 of Set 12 | doha
# Processing Record 9 of Set 12 | tahoua
# Processing Record 10 of Set 12 | camapua
# Processing Record 11 of Set 12 | baghdad
# Processing Record 12 of Set 12 | amboise
# Processing Record 13 of Set 12 | puri
# Processing Record 14 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 12 | srednekolymsk
# Processing Record 16 of Set 12 | oeiras
# Processing Record 17 of Set 12 | seoul
# Processing Record 18 of Set 12 | ramanuj ganj
# Processing Record 19 of Set 12 | papayal
# Processing Record 20 of Set 12 | komsomolskiy
# Processing Record 21 of Set 12 | ko samui
# Processing Record 22 of Set 12 | hamilton
# Processing Record 23 of Set 12 | siddapur
# Processing Record 24 of Set 12 | beloha
# Processing Record 25 of Set 12 | kathu
# Processing Record 26 of Set 12 | benguela
# Processing Record 27 of Set 12 | fayaoue
# Processing Record 28 of Set 12 | russell
# Processing Record 29 of Set 12 | taltal
# Processing Record 30 of Set 12 | puerto guzman
# Processing Record 31 of Set 12 | chifeng
# Processing Record 32 of Set 12 | alanya
# Processing Record 33 of Set 12 | pringsewu
# Processing Record 34 of Set 12 | porto belo
# Processing Record 35 of Set 12 | braganca
# Processing Record 36 of Set 12 | beboto
# Processing Record 37 of Set 12 | sambava
# Processing Record 38 of Set 12 | lahij
# Processing Record 39 of Set 12 | ondangwa
# Processing Record 40 of Set 12 | bama
# Processing Record 41 of Set 12 | axim
# Processing Record 42 of Set 12 | san carlos del zulia
# Processing Record 43 of Set 12 | bara
# Processing Record 44 of Set 12 | marsaxlokk
# Processing Record 45 of Set 12 | kassala
# Processing Record 46 of Set 12 | broken hill
# Processing Record 47 of Set 12 | savalou
# Processing Record 48 of Set 12 | kaluga
# Processing Record 49 of Set 12 | ilulissat
# Processing Record 50 of Set 12 | rocha
# Processing Record 1 of Set 13 | fundacion
# Processing Record 2 of Set 13 | paamiut
# Processing Record 3 of Set 13 | puertollano
# Processing Record 4 of Set 13 | kangundo
# Processing Record 5 of Set 13 | shwebo
# Processing Record 6 of Set 13 | cap-aux-meules
# Processing Record 7 of Set 13 | port antonio
# Processing Record 8 of Set 13 | itarema
# Processing Record 9 of Set 13 | caravelas
# Processing Record 10 of Set 13 | pecos
# Processing Record 11 of Set 13 | boralday
# Processing Record 12 of Set 13 | sarahan
# Processing Record 13 of Set 13 | gurupi
# Processing Record 14 of Set 13 | bairiki
# Processing Record 15 of Set 13 | inta
# Processing Record 16 of Set 13 | areosa
# Processing Record 17 of Set 13 | talara
# Processing Record 18 of Set 13 | choya
# Processing Record 19 of Set 13 | bridgwater
# Processing Record 20 of Set 13 | nishihara
# Processing Record 21 of Set 13 | bilma
# Processing Record 22 of Set 13 | idaho falls
# Processing Record 23 of Set 13 | villa hayes
# Processing Record 24 of Set 13 | necochea
# Processing Record 25 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | oum hadjer
# Processing Record 27 of Set 13 | okakarara
# Processing Record 28 of Set 13 | acurenam
# Processing Record 29 of Set 13 | ginir
# Processing Record 30 of Set 13 | mananara
# Processing Record 31 of Set 13 | chimbote
# Processing Record 32 of Set 13 | mehamn
# Processing Record 33 of Set 13 | faya
# Processing Record 34 of Set 13 | huilong
# Processing Record 35 of Set 13 | imbituba
# Processing Record 36 of Set 13 | libenge
# Processing Record 37 of Set 13 | lahad datu
# Processing Record 38 of Set 13 | fasa
# Processing Record 39 of Set 13 | andenes
# Processing Record 40 of Set 13 | liwale
# Processing Record 41 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 13 | jutai
# Processing Record 43 of Set 13 | richards bay
# Processing Record 44 of Set 13 | scarborough
# Processing Record 45 of Set 13 | hornepayne
# Processing Record 46 of Set 13 | waddan
# Processing Record 47 of Set 13 | poya
# Processing Record 48 of Set 13 | araouane
# Processing Record 49 of Set 13 | coos bay
# Processing Record 50 of Set 13 | potsdam
# Processing Record 1 of Set 14 | hun
# Processing Record 2 of Set 14 | mahonda
# Processing Record 3 of Set 14 | aguie
# Processing Record 4 of Set 14 | morondava
# Processing Record 5 of Set 14 | havre-saint-pierre
# Processing Record 6 of Set 14 | kousseri
# Processing Record 7 of Set 14 | raga
# Processing Record 8 of Set 14 | bambanglipuro
# Processing Record 9 of Set 14 | wadi musa
# Processing Record 10 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 14 | ankang
# Processing Record 12 of Set 14 | kaeo
# Processing Record 13 of Set 14 | wuda
# Processing Record 14 of Set 14 | lazaro cardenas
# Processing Record 15 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 14 | kutum
# Processing Record 17 of Set 14 | elizabeth city
# Processing Record 18 of Set 14 | andrelandia
# Processing Record 19 of Set 14 | hamina
# Processing Record 20 of Set 14 | olafsvik
# Processing Record 21 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 22 of Set 14 | jacksonville
# Processing Record 23 of Set 14 | shingu
# Processing Record 24 of Set 14 | kuytun
# Processing Record 25 of Set 14 | cabedelo
# Processing Record 26 of Set 14 | mildura
# Processing Record 27 of Set 14 | uvalde
# Processing Record 28 of Set 14 | gawler
# Processing Record 29 of Set 14 | hobyo
# Processing Record 30 of Set 14 | tigil
# Processing Record 31 of Set 14 | koulikoro
# Processing Record 32 of Set 14 | villazon
# Processing Record 33 of Set 14 | ulladulla
# Processing Record 34 of Set 14 | thohoyandou
# Processing Record 35 of Set 14 | bolshaya murta
# City not found. Skipping...
# Processing Record 36 of Set 14 | hovd
# Processing Record 37 of Set 14 | omsukchan
# Processing Record 38 of Set 14 | yaan
# Processing Record 39 of Set 14 | vaitape
# Processing Record 40 of Set 14 | san cristobal
# Processing Record 41 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 14 | sao filipe
# Processing Record 43 of Set 14 | luchegorsk
# Processing Record 44 of Set 14 | karaton
# Processing Record 45 of Set 14 | abu samrah
# Processing Record 46 of Set 14 | milici
# Processing Record 47 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 48 of Set 14 | san pedro
# Processing Record 49 of Set 14 | hashimoto
# Processing Record 50 of Set 14 | ishigaki
# Processing Record 1 of Set 15 | ures
# Processing Record 2 of Set 15 | arman
# Processing Record 3 of Set 15 | skibbereen
# Processing Record 4 of Set 15 | grindavik
# Processing Record 5 of Set 15 | sobolevo
# Processing Record 6 of Set 15 | borovoy
# Processing Record 7 of Set 15 | duku
# Processing Record 8 of Set 15 | inirida
# Processing Record 9 of Set 15 | yongan
# Processing Record 10 of Set 15 | rosita
# Processing Record 11 of Set 15 | fort william
# Processing Record 12 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 15 | nemuro
# Processing Record 14 of Set 15 | poltavka
# Processing Record 15 of Set 15 | sistranda
# Processing Record 16 of Set 15 | nome
# Processing Record 17 of Set 15 | diofior
# Processing Record 18 of Set 15 | lingao
# Processing Record 19 of Set 15 | sawtell
# Processing Record 20 of Set 15 | salvador
# Processing Record 21 of Set 15 | anuchino
# Processing Record 22 of Set 15 | adet
# Processing Record 23 of Set 15 | santiago
# Processing Record 24 of Set 15 | tapah
# Processing Record 25 of Set 15 | galveston
# Processing Record 26 of Set 15 | cururupu
# Processing Record 27 of Set 15 | oussouye
# Processing Record 28 of Set 15 | kontagora
# Processing Record 29 of Set 15 | quatre cocos
# Processing Record 30 of Set 15 | zlatoustovsk
# City not found. Skipping...
# Processing Record 31 of Set 15 | san jose
# Processing Record 32 of Set 15 | clarence town
# Processing Record 33 of Set 15 | avera
# Processing Record 34 of Set 15 | celestun
# Processing Record 35 of Set 15 | tsiroanomandidy
# Processing Record 36 of Set 15 | lavumisa
# Processing Record 37 of Set 15 | pafos
# Processing Record 38 of Set 15 | mafeteng
# Processing Record 39 of Set 15 | akyab
# Processing Record 40 of Set 15 | vetlanda
# Processing Record 41 of Set 15 | toba tek singh
# Processing Record 42 of Set 15 | faranah
# Processing Record 43 of Set 15 | houma
# Processing Record 44 of Set 15 | hurghada
# Processing Record 45 of Set 15 | lakatoro
# Processing Record 46 of Set 15 | urumqi
# Processing Record 47 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 15 | kodinsk

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kiama      AU -34.6833  150.8667     60.58        78           0
# 1    Albany      US  42.6001  -73.9662     95.59        34          35
# 2   Ushuaia      AR -54.8000  -68.3000     40.66        70          75
# 3    Castro      BR -24.7911  -50.0119     68.52        50          81
# 4     Along      IN  28.1667   94.7667     75.16        98         100
# 5  Calvinia      ZA -31.4707   19.7760     48.96        72           1
# 6   Cascais      PT  38.6979   -9.4215     69.94        70          78
# 7    Hirara      JP  24.8000  125.2833     84.81        72          32
# 8  Bengkulu      ID  -3.8004  102.2655     73.72        90          97
# 9  Thompson      CA  55.7435  -97.8558     66.36        39          75
#
#    Wind Speed Current Description
# 0        5.01           clear sky
# 1        8.93       moderate rain
# 2        1.14       broken clouds
# 3        5.70       broken clouds
# 4        0.92     overcast clouds
# 5        1.99           clear sky
# 6       18.01       broken clouds
# 7        6.15    scattered clouds
# 8        3.51     overcast clouds
# 9        3.44       broken clouds

# %%
# Create the output file (CSV).
#output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
